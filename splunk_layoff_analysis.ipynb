# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/layoff_data/Splunk Talent 2023 - Form Responses 1.csv')
data.head()
# Out:
#   xSplunkers, add your info here!! https://forms.gle/AAryt8nDnNvHbwZy5  \
# 0                                          Timestamp
# 1                                  2/1/2023 10:47:12
# 2                                  2/1/2023 10:53:54
# 3                                  2/1/2023 11:10:06
# 4                                  2/1/2023 11:24:26
#
#    Unnamed: 1 Unnamed: 2                        Unnamed: 3  \
# 0  First Name  Last Name                  Former Job Title
# 1          Ed  Hunsinger                    Chief of Staff
# 2        Andy   Garlikov   Senior Product Advisory Manager
# 3       Aimée     Barrie  Global Content Marketing Manager
# 4      Nusair        Haq          Associate Product Manger
#
#                                           Unnamed: 4  \
# 0                                    Team / Function
# 1                               Platform Experiences
# 2  EPAT (Executive Councils, Customer Experience ...
# 3                                Talent Acquisition
# 4                         Splunk UI - Design Systems
#
#   If you've gotten a new job and want to be crossed off the list, email splunk@edrabbit.com  \
# 0                                               City
# 1                                  San Francisco, CA
# 2                                      San Mateo, CA
# 3                                  Vancouver, Canada
# 4                                            Toronto
#
#                             Unnamed: 6  \
# 0                              Remote?
# 1                  Remote Only, Hybrid
# 2  Remote Only, Hybrid, In Office Only
# 3                  Remote Only, Hybrid
# 4                          Remote Only
#
#                                        Unnamed: 7  \
# 0                                    LinkedIn URL
# 1        https://www.linkedin.com/in/edhunsinger/
# 2                www.linkedin.com/in/andygarlikov
# 3  https://www.linkedin.com/in/aim%C3%A9e-barrie/
# 4          https://www.linkedin.com/in/nusair-haq
#
#                                           Unnamed: 8
# 0                          Additional comments/notes
# 1                                                NaN
# 2  Looking primarily for customer marketing, cust...
# 3                                                NaN
# 4                                                NaN

# %%
print(data.shape)

for col in data.columns:
    print(col)
# Out:
# (125, 9)
# xSplunkers, add your info here!! https://forms.gle/AAryt8nDnNvHbwZy5
# Unnamed: 1
# Unnamed: 2
# Unnamed: 3
# Unnamed: 4
# If you've gotten a new job and want to be crossed off the list, email splunk@edrabbit.com
# Unnamed: 6
# Unnamed: 7
# Unnamed: 8

# %%
data = data.rename(columns={
    'xSplunkers, add your info here!! https://forms.gle/AAryt8nDnNvHbwZy5': 'Timestamp',
    'Unnamed: 1': 'First Name',
    'Unnamed: 2': 'Last Name',
    'Unnamed: 3': 'Former Job Title',
    'Unnamed: 4': 'Team / Function',
    'If you\'ve gotten a new job and want to be crossed off the list, email splunk@edrabbit.com': 'City',
    'Unnamed: 6': 'Remote',
    'Unnamed: 7': 'LinkedIn URL',
    'Unnamed: 8': 'comments'
})

# %%
onsite_eng = data[
    (data['Former Job Title'].isna() | data['Former Job Title'].str.contains('engineer', case=False)) &
    (data['Former Job Title'].isna() | ~data['Former Job Title'].str.contains('frontend', case=False)) &
    (data['Remote'].isna() | data['Remote'].str.contains('hybrid', case=False) | data['Remote'].str.contains('office', case=False))
    ]
print(onsite_eng.shape)
print(onsite_eng.head())
# Out:
# (54, 9)
#             Timestamp First Name Last Name  \
# 11  2/1/2023 12:34:30        Jun     Sakai
# 12  2/1/2023 12:38:13     Connor    Barker
# 14  2/1/2023 12:48:23    William    Nguyen
# 16  2/1/2023 12:57:30      Damon   Dunmire
# 18  2/1/2023 13:33:25      Clara       Lee
#
#                          Former Job Title  \
# 11                   Sr Software Engineer
# 12                      Software Engineer
# 14                      Software Engineer
# 16   Position Principal Advisory Engineer
# 18                  Sr. Software Engineer
#
#                                      Team / Function           City  \
# 11                                        Splunkbase       HONOLULU
# 12                                               UDF  San Francisco
# 14                                  Backend engineer        Fremont
# 16                       Early Product Adoption Team          ESSEX
# 18  Admin Experiences Customization - Admin UI pages  San Francisco
#
#                                  Remote  \
# 11                  Remote Only, Hybrid
# 12                               Hybrid
# 14  Remote Only, Hybrid, In Office Only
# 16                  Remote Only, Hybrid
# 18                  Remote Only, Hybrid
#
#                                          LinkedIn URL  \
# 11              https://www.linkedin.com/in/sakaijun/
# 12           https://www.linkedin.com/in/connorbarkr/
# 14  https://www.linkedin.com/in/william-nguyen-436...
# 16        www.linkedin.com/in/damon-dunmire-952355119
# 18                 linkedin.com/in/clara-lee-6b4b003/
#
#                                              comments
# 11  I just moved to Hawaii last year, so I'm looki...
# 12                                                NaN
# 14                                                NaN
# 16                                                NaN
# 18                                        UI engineer

# %%
ca_onsite_eng = onsite_eng[ onsite_eng['City'].isna() | 
                            onsite_eng['City'].str.contains('CA', case=False) |
                            onsite_eng['City'].str.contains('San Francisco', case=False) |
                            onsite_eng['City'].str.contains('San Mateo', case=False) |
                            onsite_eng['City'].str.contains('Santa Clara', case=False)
                           ]
print(ca_onsite_eng.shape)
print(ca_onsite_eng.head())
# Out:
# (22, 9)
#             Timestamp First Name Last Name       Former Job Title  \
# 12  2/1/2023 12:38:13     Connor    Barker      Software Engineer
# 18  2/1/2023 13:33:25      Clara       Lee  Sr. Software Engineer
# 19  2/1/2023 14:01:43      irina  korobova      Software Engineer
# 23  2/1/2023 14:28:44      David       Kim      Software Engineer
# 28  2/1/2023 14:55:39       anny        he      software engineer
#
#                                      Team / Function             City  \
# 12                                               UDF    San Francisco
# 18  Admin Experiences Customization - Admin UI pages    San Francisco
# 19                                Design System Team    San Francisco
# 23                 UDF (Unified Dashboard Framework)  Los Angeles, CA
# 28                               developer ecosystem    san francisco
#
#                  Remote                                       LinkedIn URL  \
# 12               Hybrid           https://www.linkedin.com/in/connorbarkr/
# 18  Remote Only, Hybrid                 linkedin.com/in/clara-lee-6b4b003/
# 19  Remote Only, Hybrid  https://www.linkedin.com/in/irina-korobova-741...
# 23  Remote Only, Hybrid             https://www.linkedin.com/in/davidhk21/
# 28               Hybrid                 https://www.linkedin.com/in/annyhe
#
#        comments
# 12          NaN
# 18  UI engineer
# 19          NaN
# 23          NaN
# 28          NaN

# %%
data_ca_onsite_eng = ca_onsite_eng[
    ca_onsite_eng['Former Job Title'].isna() |
    ca_onsite_eng['Former Job Title'].str.contains('data', case=False) |
    ca_onsite_eng['Team / Function'].isna() |
    ca_onsite_eng['Team / Function'].str.contains('data', case=False)
]

print(data_ca_onsite_eng.shape)
print(data_ca_onsite_eng.head())
# Out:
# (5, 9)
#               Timestamp First Name     Last Name             Former Job Title  \
# 36    2/1/2023 15:51:36     Shelly         Cheng            Software Engineer
# 45    2/1/2023 17:23:42    Patrick          Wied  Principal Software Engineer
# 49    2/1/2023 19:29:56      Aditi          Nath            Software Engineer
# 112   2/6/2023 17:18:54   Srinivas  Pasagadugula     Senior Software Engineer
# 122  2/11/2023 19:38:36    Wajahat        Jawaid      Senior Android Engineer
#
#                          Team / Function           City  \
# 36                    Data Visualization  San Francisco
# 45   Splunkbase & Data Visualization Eng  San Francisco
# 49        Data Visualization Engineering  San Francisco
# 112                Cloud Data Collection    San Jose,CA
# 122                                  NaN            NaN
#
#                                   Remote  \
# 36   Remote Only, Hybrid, In Office Only
# 45                                Hybrid
# 49                                Hybrid
# 112  Remote Only, Hybrid, In Office Only
# 122  Remote Only, Hybrid, In Office Only
#
#                                           LinkedIn URL  \
# 36           https://www.linkedin.com/in/shellyscheng/
# 45             https://www.linkedin.com/in/patrickwied
# 49              https://www.linkedin.com/in/aditi-nath
# 112   https://www.linkedin.com/in/srinivaspasagadugula
# 122  https://www.linkedin.com/in/wajahat-jawaid-998...
#
#                                               comments
# 36   personal portfolio: https://shellyscheng.githu...
# 45                                                 NaN
# 49                                                 NaN
# 112  Full Stack Engineer, Backend Engineer \nExperi...
# 122                                                NaN
